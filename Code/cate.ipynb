# %%
# Game
import causalitygame as cg

# Agents
from causalitygame.agents.impl.RandomAgent import RandomAgent
from causalitygame.agents.impl.ExhaustiveAgent import ExhaustiveAgent


# Define the agents
agents = [(f"Random Agent {i}", RandomAgent(seed=911 + i)) for i in range(1, 1)]
# Add an exhaustive agent
agents.append(("Exhaustive Agent", ExhaustiveAgent()))
# Game Instance
game_instance_path = (
    "causalitygame/data/game_instances/cate/ideal_gas_instance.json"
)
# Create a game
game = cg.Game(agents=agents, game_spec=game_instance_path)
# Run the game
runs = game.run()
# Out:
#   9%|▉         | 1/11 [00:03<00:38,  3.88s/it]
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
#  18%|█▊        | 2/11 [00:05<00:24,  2.69s/it]
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
#  27%|██▋       | 3/11 [00:09<00:23,  2.97s/it]
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
#  45%|████▌     | 5/11 [00:22<00:30,  5.01s/it]
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
#  55%|█████▍    | 6/11 [00:47<00:54, 10.80s/it]
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
#  64%|██████▎   | 7/11 [00:49<00:32,  8.16s/it]
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
#  73%|███████▎  | 8/11 [01:09<00:34, 11.65s/it]
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
#  91%|█████████ | 10/11 [01:26<00:10, 10.37s/it]
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# 100%|██████████| 11/11 [06:03<00:00, 33.02s/it]
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0

# %%
game.plot()
# Out:
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# Y_t1: [], Y_t0: []
# Empirical CATE: 0.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 game.plot()
#
# File ~/Desktop/Business/Research/Causality/Code/causalitygame/game/Game.py:137, in Game.plot(self)
#     134 behavior_scores, deliverable_scores = [], []
#     135 for i in range(len(run["history"])):
#     136     current_behavior_score, current_deliverable_score = (
# --> 137         game_instance.mission.evaluate(
#     138             game_instance.scm, run["history"].iloc[: i + 1]
#     139         )
#     140     )
#     141     behavior_scores.append(current_behavior_score)
#     142     deliverable_scores.append(current_deliverable_score)
#
# File ~/Desktop/Business/Research/Causality/Code/causalitygame/mission/impl/CATEMission.py:106, in CATEMission.evaluate(self, scm, history)
#     103 CATE = np.mean(CATEs)
#     104 # Comput the empirical average CATE
#     105 empirical_CATE = np.mean(
# --> 106     [empirical_cate_function(Y, T, X) for Y, T, X in cate_experiments]
#     107 )
#     108 print("Empirical CATE:", empirical_CATE)
#     110 behavior_score = self.behavior_metric.evaluate(history)
#
# File ~/Desktop/Business/Research/Causality/Code/causalitygame/agents/impl/RandomAgent.py:131, in RandomAgent._cate_task.<locals>.compute_cate(Y, T, Z)
#     130 def compute_cate(Y, T, Z):
# --> 131     return compute_empirical_cate_fuzzy(
#     132         query={"Y": Y, "T": T, "Z": Z},
#     133         data=self.past_data,
#     134         distance_threshold=10**2,
#     135     )
#
# File ~/Desktop/Business/Research/Causality/Code/causalitygame/lib/scripts/empiricalCATE.py:54, in compute_empirical_cate_fuzzy(query, data, distance_threshold)
#      51     for treatment_val, records in treatments.items():
#      52         Y_records.extend(records)
# ---> 54 Y_t1 = get_close_matches(Y_records, t1)
#      55 Y_t0 = get_close_matches(Y_records, t0)
#      57 print(f"Y_t1: {Y_t1}, Y_t0: {Y_t0}")
#
# File ~/Desktop/Business/Research/Causality/Code/causalitygame/lib/scripts/empiricalCATE.py:40, in compute_empirical_cate_fuzzy.<locals>.get_close_matches(records, treatment_value)
#      38     for key, val in context.items():
#      39         distances.append(abs(record.get(key, 0) - val))
# ---> 40     if all(d <= distance_threshold for d in distances):
#      41         close.append(record[Y])
#      42 return close
#
# KeyboardInterrupt:
